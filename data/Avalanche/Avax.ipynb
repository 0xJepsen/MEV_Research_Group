# %%
import requests
import pandas as pd

# %%
ADDRESS_TO_INSPECT = '0x60ae616a2155ee3d9a68541ba4544862310933d4'
API_KEY='ZWW14IE28IK2D3RT71CKRCV93VACQYYASJ'
LATEST_BLOCK='12037952'
## r = requests.get('https://api.snowtrace.io/api?module=account&action=tokentx&address={}&startblock=0&endblock={}&sort=asc&apikey={}'.format(ADDRESS_TO_INSPECT, LATEST_BLOCK, API_KEY))

g = requests.get('https://api.snowtrace.io/api?module=account&action=txlist&address=0x60ae616a2155ee3d9a68541ba4544862310933d4&startblock=1&endblock=99999999&sort=asc&apikey=ZWW14IE28IK2D3RT71CKRCV93VACQYYASJ')

# %%
a = g.json()
a['result']
a
# Out:
# {'status': '1',
#  'message': 'OK',
#  'result': [{'blockNumber': '2486393',
#    'timeStamp': '1624779817',
#    'hash': '0x97b37f00ad5393e126940747808f8c575c081a9e154e39e772c01838d91f672c',
#    'nonce': '3',
#    'blockHash': '0x1ab405c242922a3f4e404fd088bba1d0a64f2699658d67116666f8947ffa6c08',
#    'transactionIndex': '1',
#    'from': '0x5d3e4c0fe11e0ae4c32f0ff74b4544c49538ac61',
#    'to': '',
#    'value': '0',
#    'gas': '3862841',
#    'gasPrice': '225000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '0x60ae616a2155ee3d9a68541ba4544862310933d4',
#    'cumulativeGasUsed': '4054366',
#    'gasUsed': '3862841',
#    'confirmations': '9551744'},
#   {'blockNumber': '2504194',
#    'timeStamp': '1624941631',
#    'hash': '0x4089559454d19a59c189e4295093de266d1499e0483fe635607ae206ba70e87b',
#    'nonce': '11',
#    'blockHash': '0x3c74fc540b5cd031c337d6e224956519f855d182581ae07ae94d98be852d4746',
# ...

# %%
df = pd.DataFrame(a['result'])

# %%
len(df)
# Out:
# 10000

# %%
df.head()
# Out:
#   blockNumber   timeStamp                                               hash  \
# 0     2486393  1624779817  0x97b37f00ad5393e126940747808f8c575c081a9e154e...
# 1     2504194  1624941631  0x4089559454d19a59c189e4295093de266d1499e0483f...
# 2     2504226  1624941782  0xd8ae93395dc89a4c6c36abbf30c2f3a4f4193c8c81cf...
# 3     2504337  1624942853  0x27a071a8aef03fd44427caffb0a0587bea5ae1936541...
# 4     2504340  1624942890  0x2ee21d842f067783787209b3be11ba0195ae91d9444e...
#
#   nonce                                          blockHash transactionIndex  \
# 0     3  0x1ab405c242922a3f4e404fd088bba1d0a64f2699658d...                1
# 1    11  0x3c74fc540b5cd031c337d6e224956519f855d182581a...                0
# 2    13  0xfba9d5e115ce1a7ab2f3f347cad8b1879cbaaae66267...                0
# 3    15  0x25e5aa897e76ff97cbc912df82c5d77beb786dfda87a...                0
# 4    16  0x95b8b9d0cde26cbd65f11363b59b62e5775dc0f2f435...                0
#
# ...

# %%
df1 = df[df['tokenSymbol']=='WAVAX']

# %%
df1
# Out:
#      blockNumber   timeStamp  \
# 0       11271304  1645576853
# 1       11271309  1645576866
# 2       11271321  1645576893
# 3       11271686  1645577640
# 6       11271686  1645577640
# ...          ...         ...
# 9991    11428699  1645897780
# 9993    11428699  1645897780
# 9996    11428701  1645897786
# 9997    11428720  1645897822
# 9999    11428720  1645897822
#
#                                                    hash nonce  \
# 0     0x2d1d261b84757b7f45f9f53363af395d5007a3c5fc13...   356
# 1     0xb0ec55660323cfcd25cf7bf14d2366edc3199bce6759...   357
# 2     0xb2ae85e16000f5c3368af72398d41544e786cea4f762...   359
# 3     0x4b4c1004e61aef3f72bdbab4678c111828545684d7c9...  5537
# 6     0x23b74c16a7b2fb190415a9e88b7750903247626930d4...   987
# ...                                                 ...   ...
# 9991  0x8a54285093e6472c9cc42afb46eac3e693b0c36802c0...  6140
# 9993  0x8a54285093e6472c9cc42afb46eac3e693b0c36802c0...  6140
# ...

# %%
df2 = df1[df1['from']==ADDRESS_TO_INSPECT]
df2
# Out:
#      blockNumber   timeStamp  \
# 1       11271309  1645576866
# 3       11271686  1645577640
# 7       11271761  1645577796
# 11      11271957  1645578210
# 16      11272010  1645578319
# ...          ...         ...
# 9987    11428684  1645897746
# 9991    11428699  1645897780
# 9993    11428699  1645897780
# 9997    11428720  1645897822
# 9999    11428720  1645897822
#
#                                                    hash nonce  \
# 1     0xb0ec55660323cfcd25cf7bf14d2366edc3199bce6759...   357
# 3     0x4b4c1004e61aef3f72bdbab4678c111828545684d7c9...  5537
# 7     0x61d5b2ae5c0d7c8f767f6c221407d153b145b4f136a6...  5515
# 11    0xe950471bfebdc5c2cae84d88860540b3024be0a2b034...  5538
# 16    0xde30733c44524cdd7d44f55fb89f8e532a77f4f1ef6f...   377
# ...                                                 ...   ...
# 9987  0xb734746c8b0a3d95bae4bce258542fe085916dbd6cc2...  6093
# 9991  0x8a54285093e6472c9cc42afb46eac3e693b0c36802c0...  6140
# ...

# %%
df3 = df1[df1['to']==ADDRESS_TO_INSPECT]
df3
# Out:
#      blockNumber   timeStamp  \
# 0       11271304  1645576853
# 2       11271321  1645576893
# 6       11271686  1645577640
# 10      11271761  1645577796
# 14      11271957  1645578210
# ...          ...         ...
# 9976    11428672  1645897725
# 9980    11428681  1645897742
# 9984    11428681  1645897742
# 9990    11428684  1645897746
# 9996    11428701  1645897786
#
#                                                    hash nonce  \
# 0     0x2d1d261b84757b7f45f9f53363af395d5007a3c5fc13...   356
# 2     0xb2ae85e16000f5c3368af72398d41544e786cea4f762...   359
# 6     0x23b74c16a7b2fb190415a9e88b7750903247626930d4...   987
# 10    0xcb26e92f21598a775b47b84996c09a2d08c96da9c8bf...  1582
# 14    0xcd5aae8ed59c7f29e8ea3831a9154fa696be67c2f0d0...  1130
# ...                                                 ...   ...
# 9976  0x0e56d6c3939f13772afe6bbe1e34067f28ad82857fec...  1868
# 9980  0x9ead34a76c4260eefcd8bea9ec304006c108f64eb70a...  1726
# ...

# %%
fr = df2['value'].astype('float').sum() 
fr = fr / (10**18)
to = df3['value'].astype('float').sum() 
to = to / (10**18)
profit = to - fr
profit = profit * 75
profit
# Out:
# 253546.11316837108
