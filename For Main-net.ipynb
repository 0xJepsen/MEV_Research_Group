# %%
import requests
import pandas as pd

# %%
ADDRESS_TO_INSPECT = '0x0000000000c521824eaff97eac7b73b084ef9306'
API_KEY='2MA1VCBWWYMIAT5RCQHQJXT225X27WQP49'
LATEST_BLOCK='11821746'
r = requests.get('https://api.etherscan.io/api?module=account&action=tokentx&address={}&startblock=0&endblock=27025780&sort=asc&apikey={}'.format(ADDRESS_TO_INSPECT, API_KEY))
r
# Out:
# <Response [200]>

# %%
a = r.json()
a['result']
# Out:
# [{'blockNumber': '12512192',
#   'timeStamp': '1622062359',
#   'hash': '0x7aad0f077757af8afd2ba1076d8123a1aec15a27523fd4468e015d4466a2c0fd',
#   'nonce': '43',
#   'blockHash': '0x718f534a2d7fd9ae8c34507400b8fec385f09b845c244b8c00f08c7f926b185e',
#   'from': '0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc',
#   'contractAddress': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#   'to': '0x0000000000c521824eaff97eac7b73b084ef9306',
#   'value': '1003260570151787735',
#   'tokenName': 'Wrapped Ether',
#   'tokenSymbol': 'WETH',
#   'tokenDecimal': '18',
#   'transactionIndex': '69',
#   'gas': '150591',
#   'gasPrice': '46000000000',
#   'gasUsed': '138585',
#   'cumulativeGasUsed': '9461499',
#   'input': 'deprecated',
#   'confirmations': '1830417'},
#  {'blockNumber': '12549858',
#   'timeStamp': '1622567758',
#   'hash': '0x96118dbe443233e915acca657c38f70b3311861bad745b64a0b9fcaff63e2455',
#   'nonce': '78',
# ...

# %%
df = pd.DataFrame(a['result'])

# %%
len(df)
# Out:
# 81

# %%
df.head()
# Out:
#   blockNumber   timeStamp                                               hash  \
# 0    12512192  1622062359  0x7aad0f077757af8afd2ba1076d8123a1aec15a27523f...
# 1    12549858  1622567758  0x96118dbe443233e915acca657c38f70b3311861bad74...
# 2    12549876  1622567994  0xeb6db3016ce282eb598cbbdbb64ce3e4edfe781ff765...
# 3    12563691  1622752517  0x16af3e116a017dfb3d948118df5238240609b2d01bf5...
# 4    12576087  1622918262  0x7c5f2cbdc5e779336b54248499807688cb653638c72d...
#
#   nonce                                          blockHash  \
# 0    43  0x718f534a2d7fd9ae8c34507400b8fec385f09b845c24...
# 1    78  0x74a82cabc4b35cfb56194f9bafb5c1d18a675e3dc6a4...
# 2    79  0x6dab7303e246ece5bb5708d9c16b84136aca9e8ada89...
# 3   112  0x8cdae3d0044fa7287d879e20d4c27314396c6ac67771...
# 4   146  0xc9aec8fda1f5ccf148122a183f8c2a69bd6f1a04792b...
#
#                                          from  \
# 0  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc
# 1  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc
# ...

# %%
df1 = df[df['tokenSymbol']=='WETH']

# %%
df1
# Out:
#    blockNumber   timeStamp                                               hash  \
# 0     12512192  1622062359  0x7aad0f077757af8afd2ba1076d8123a1aec15a27523f...
# 1     12549858  1622567758  0x96118dbe443233e915acca657c38f70b3311861bad74...
# 2     12549876  1622567994  0xeb6db3016ce282eb598cbbdbb64ce3e4edfe781ff765...
# 3     12563691  1622752517  0x16af3e116a017dfb3d948118df5238240609b2d01bf5...
# 4     12576087  1622918262  0x7c5f2cbdc5e779336b54248499807688cb653638c72d...
# ..         ...         ...                                                ...
# 60    13201987  1631329728  0x8a07144ea781528b5e8b9709f94a6b3644e9f5d2046b...
# 61    13205483  1631377050  0xc6f5f3056e2599d427c0b190aed5e4596957af1bb9ea...
# 63    13207219  1631400382  0x5e249e8bc8a7d6483bae378496b3398d3f272f5e6f05...
# 64    13217957  1631544447  0x09958ac756e7d7d70cc999838adf1571de7e171e4dc7...
# 65    13219565  1631565128  0x0725148f1d98dd72709003a532ab23c3c80a5c6a0629...
#
# ...

# %%
df2 = df1[df1['from']==ADDRESS_TO_INSPECT]
df2
# Out:
#    blockNumber   timeStamp                                               hash  \
# 2     12549876  1622567994  0xeb6db3016ce282eb598cbbdbb64ce3e4edfe781ff765...
# 46    13164783  1630832430  0xabc88a0b5b856b7ae58df3855d02af92ed5ee0f25348...
#
#    nonce                                          blockHash  \
# 2     79  0x6dab7303e246ece5bb5708d9c16b84136aca9e8ada89...
# 46  2197  0xe58a38b24f88c29fcaed4d24de0b169a3bc3d5b20c90...
#
#                                           from  \
# 2   0x0000000000c521824eaff97eac7b73b084ef9306
# 46  0x0000000000c521824eaff97eac7b73b084ef9306
#
#                                contractAddress  \
# 2   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 46  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#                                             to                value  \
# 2   0x000000000027d2efc283613d0c3e24a8b430c4d8  3511270487456434430
# 46  0x000000000027d2efc283613d0c3e24a8b430c4d8  4083988607849502141
#
# ...

# %%
df3 = df1[df1['to']==ADDRESS_TO_INSPECT]
df3
# Out:
#    blockNumber   timeStamp                                               hash  \
# 0     12512192  1622062359  0x7aad0f077757af8afd2ba1076d8123a1aec15a27523f...
# 1     12549858  1622567758  0x96118dbe443233e915acca657c38f70b3311861bad74...
# 3     12563691  1622752517  0x16af3e116a017dfb3d948118df5238240609b2d01bf5...
# 4     12576087  1622918262  0x7c5f2cbdc5e779336b54248499807688cb653638c72d...
# 5     12601657  1623259626  0xe6ea944645cc6666667e5e82490aa6c33f813dccf1b2...
# ..         ...         ...                                                ...
# 60    13201987  1631329728  0x8a07144ea781528b5e8b9709f94a6b3644e9f5d2046b...
# 61    13205483  1631377050  0xc6f5f3056e2599d427c0b190aed5e4596957af1bb9ea...
# 63    13207219  1631400382  0x5e249e8bc8a7d6483bae378496b3398d3f272f5e6f05...
# 64    13217957  1631544447  0x09958ac756e7d7d70cc999838adf1571de7e171e4dc7...
# 65    13219565  1631565128  0x0725148f1d98dd72709003a532ab23c3c80a5c6a0629...
#
# ...

# %%
fr = df2['value'].astype('float').sum() 
fr = fr / (10**18)
to = df3['value'].astype('float').sum() 
to = to / (10**18)
profit = to - fr
profit = profit * 2,503.53 ##E
profit
# Out:
# 10105.888587990843
