# %%
import requests
import pandas as pd

# %%
r = requests.get('https://api.snowtrace.io/api?module=account&action=tokentx&address=0x7393869B3317a81AC16305F549402Ad57E1A7A26&startblock=0&endblock=11815818&sort=asc&apikey=ZWW14IE28IK2D3RT71CKRCV93VACQYYASJ')

# %%
a = r.json()
a['result']
# Out:
# [{'blockNumber': '11271304',
#   'timeStamp': '1645576853',
#   'hash': '0x2d1d261b84757b7f45f9f53363af395d5007a3c5fc13a350e4ba435558b76523',
#   'nonce': '356',
#   'blockHash': '0x12f5c1750c95e35ec2f532f4635f4172602defd889c5fe3422c7b119fbc55a94',
#   'from': '0x1039184e2c81b8be5f57d939c0c42c1bb287d71b',
#   'to': '0x7393869b3317a81ac16305f549402ad57e1a7a26',
#   'contractAddress': '0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7',
#   'value': '1',
#   'tokenName': 'Wrapped AVAX',
#   'tokenSymbol': 'WAVAX',
#   'tokenDecimal': '18',
#   'transactionIndex': '3',
#   'gas': '51488',
#   'gasPrice': '60000000000',
#   'gasUsed': '51488',
#   'cumulativeGasUsed': '334830',
#   'input': 'deprecated',
#   'confirmations': '550210'},
#  {'blockNumber': '11271309',
#   'timeStamp': '1645576866',
#   'hash': '0xb0ec55660323cfcd25cf7bf14d2366edc3199bce6759665f5d9a2b817b8f3a36',
#   'nonce': '357',
#   'blockHash': '0xfb83d1d98242a12d3e256919e5f8005f9e075c98ce8d4e8d1b50608a0d8c596f',
# ...

# %%
df = pd.DataFrame(a['result'])

# %%
len(df)
# Out:
# 10000

# %%
df.head()
# Out:
#   blockNumber   timeStamp                                               hash  \
# 0    11271304  1645576853  0x2d1d261b84757b7f45f9f53363af395d5007a3c5fc13...
# 1    11271309  1645576866  0xb0ec55660323cfcd25cf7bf14d2366edc3199bce6759...
# 2    11271321  1645576893  0xb2ae85e16000f5c3368af72398d41544e786cea4f762...
# 3    11271686  1645577640  0x4b4c1004e61aef3f72bdbab4678c111828545684d7c9...
# 4    11271686  1645577640  0x4b4c1004e61aef3f72bdbab4678c111828545684d7c9...
#
#   nonce                                          blockHash  \
# 0   356  0x12f5c1750c95e35ec2f532f4635f4172602defd889c5...
# 1   357  0xfb83d1d98242a12d3e256919e5f8005f9e075c98ce8d...
# 2   359  0x449e85bba6eb3d1baaa6cdbd980d9ad5c0ca4caf8e95...
# 3  5537  0x86a7c7d3d390340a97d9a04d617ade735cbdc4491e8b...
# 4  5537  0x86a7c7d3d390340a97d9a04d617ade735cbdc4491e8b...
#
#                                          from  \
# 0  0x1039184e2c81b8be5f57d939c0c42c1bb287d71b
# 1  0x7393869b3317a81ac16305f549402ad57e1a7a26
# ...

# %%
df1 = df[df['tokenSymbol']=='WAVAX']

# %%
df1
# Out:
#      blockNumber   timeStamp  \
# 0       11271304  1645576853
# 1       11271309  1645576866
# 2       11271321  1645576893
# 3       11271686  1645577640
# 6       11271686  1645577640
# ...          ...         ...
# 9991    11428699  1645897780
# 9993    11428699  1645897780
# 9996    11428701  1645897786
# 9997    11428720  1645897822
# 9999    11428720  1645897822
#
#                                                    hash nonce  \
# 0     0x2d1d261b84757b7f45f9f53363af395d5007a3c5fc13...   356
# 1     0xb0ec55660323cfcd25cf7bf14d2366edc3199bce6759...   357
# 2     0xb2ae85e16000f5c3368af72398d41544e786cea4f762...   359
# 3     0x4b4c1004e61aef3f72bdbab4678c111828545684d7c9...  5537
# 6     0x23b74c16a7b2fb190415a9e88b7750903247626930d4...   987
# ...                                                 ...   ...
# 9991  0x8a54285093e6472c9cc42afb46eac3e693b0c36802c0...  6140
# 9993  0x8a54285093e6472c9cc42afb46eac3e693b0c36802c0...  6140
# ...

# %%
df2 = df1[df1['from']=='0x7393869b3317a81ac16305f549402ad57e1a7a26']
df2
# Out:
#      blockNumber   timeStamp  \
# 1       11271309  1645576866
# 3       11271686  1645577640
# 7       11271761  1645577796
# 11      11271957  1645578210
# 16      11272010  1645578319
# ...          ...         ...
# 9987    11428684  1645897746
# 9991    11428699  1645897780
# 9993    11428699  1645897780
# 9997    11428720  1645897822
# 9999    11428720  1645897822
#
#                                                    hash nonce  \
# 1     0xb0ec55660323cfcd25cf7bf14d2366edc3199bce6759...   357
# 3     0x4b4c1004e61aef3f72bdbab4678c111828545684d7c9...  5537
# 7     0x61d5b2ae5c0d7c8f767f6c221407d153b145b4f136a6...  5515
# 11    0xe950471bfebdc5c2cae84d88860540b3024be0a2b034...  5538
# 16    0xde30733c44524cdd7d44f55fb89f8e532a77f4f1ef6f...   377
# ...                                                 ...   ...
# 9987  0xb734746c8b0a3d95bae4bce258542fe085916dbd6cc2...  6093
# 9991  0x8a54285093e6472c9cc42afb46eac3e693b0c36802c0...  6140
# ...

# %%
df3 = df1[df1['to']=='0x7393869b3317a81ac16305f549402ad57e1a7a26']
df3
# Out:
#      blockNumber   timeStamp  \
# 0       11271304  1645576853
# 2       11271321  1645576893
# 6       11271686  1645577640
# 10      11271761  1645577796
# 14      11271957  1645578210
# ...          ...         ...
# 9976    11428672  1645897725
# 9980    11428681  1645897742
# 9984    11428681  1645897742
# 9990    11428684  1645897746
# 9996    11428701  1645897786
#
#                                                    hash nonce  \
# 0     0x2d1d261b84757b7f45f9f53363af395d5007a3c5fc13...   356
# 2     0xb2ae85e16000f5c3368af72398d41544e786cea4f762...   359
# 6     0x23b74c16a7b2fb190415a9e88b7750903247626930d4...   987
# 10    0xcb26e92f21598a775b47b84996c09a2d08c96da9c8bf...  1582
# 14    0xcd5aae8ed59c7f29e8ea3831a9154fa696be67c2f0d0...  1130
# ...                                                 ...   ...
# 9976  0x0e56d6c3939f13772afe6bbe1e34067f28ad82857fec...  1868
# 9980  0x9ead34a76c4260eefcd8bea9ec304006c108f64eb70a...  1726
# ...

# %%
fr = df2['value'].astype('float').sum() 
fr = fr / (10**18)
to = df3['value'].astype('float').sum() 
to = to / (10**18)
profit = to - fr
profit = profit * 75
profit
# Out:
# 253546.11316837108
